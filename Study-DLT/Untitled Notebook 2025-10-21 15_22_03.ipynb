# %%
expectations={"comb_valid_BOROUGH": "BOROUGH IS NOT NULL","comb_valid_zipcode":"ZIP_CODE IS NOT NULL"}
reverse_qa_rules="!("+" OR ".join(expectations.values())+")"
print (reverse_qa_rules)
